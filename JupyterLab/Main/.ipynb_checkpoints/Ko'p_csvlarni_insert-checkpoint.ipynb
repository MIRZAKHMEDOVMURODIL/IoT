# %%
import pandas as pd
import ibm_db
import logging
from sqlalchemy import create_engine

# %%
logging.basicConfig(filename='database_connection.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


database = "AYB_APPL"
host = "10.143.16.244"
port = "50000"
user = "IOT_DATA"
password = "asd23fgh"


dsn = (
    f"DATABASE={database};"
    f"HOSTNAME={host};"
    f"PORT={port};"
    f"PROTOCOL=TCPIP;"
    f"UID={user};"
    f"PWD={password};"
)

conn = ibm_db.connect(dsn, "", "")

if conn:
    logging.info("Connected to the database")
    print("Connected to the database")
else:
    logging.error("Failed to connect to the database")
    print("Failed to connect to the database")
    exit()
# Out:
# Connected to the database

# %%
csv_file_path = r"C:\Users\00220401626\Desktop\FMS\CsvData\2023\20231001.csv"
df = pd.read_csv(csv_file_path, encoding='cp932',dtype= object)

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
a = df['Location'].unique()
latest_data = pd.DataFrame()
df_concat = []
for location in a:
    latest_location = df[df['Location'] == location].nlargest(1, 'Timestamp')
    df_concat.append(latest_location)
latest_data = pd.concat(df_concat, ignore_index=True)

# %%
insert_query = "INSERT INTO LIQUID_PARTICLE_LAST (Location, TS_DT, VALUE_1_0, VALUE_3_0, VALUE_5_0,VALUE_10_0, VALUE_15_0, VALUE_20_0, VALUE_25_0, VALUE_50_0) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"

stmt = ibm_db.prepare(conn, insert_query)

for index, row in latest_data.iterrows():
    location = row['Location']
    timestamp = row['Timestamp']
    c1 = row['1.0μｍ']
    c3 = row['3.0μｍ']
    c5 = row['5.0μｍ']
    c10 = row['10.0μｍ']
    c15 = row['15.0μｍ']
    c20 = row['20.0μｍ']
    c25 = row['25.0μｍ']
    c50 = row['50.0μｍ']
    
    if ibm_db.execute(stmt, (location, timestamp, c1, c3, c5, c10, c15, c20, c25, c50)):
        print(f"Row {index + 1} inserted successfully")
    else:
        print(f"Error inserting row {index + 1}: {ibm_db.stmt_errormsg()}")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [12], in <cell line: 5>()
#      14 c25 = row['25.0μｍ']
#      15 c50 = row['50.0μｍ']
# ---> 17 if ibm_db.execute(stmt, (location, timestamp, c1, c3, c5, c10, c15, c20, c25, c50)):
#      18     print(f"Row {index + 1} inserted successfully")
#      19 else:
#
#  SQLCODE=-803

# %%
insert_query = "INSERT INTO LIQUID_PARTICLE (Location, TS_DT, VALUE_1_0, VALUE_3_0, VALUE_5_0,VALUE_10_0, VALUE_15_0, VALUE_20_0, VALUE_25_0, VALUE_50_0) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"

stmt = ibm_db.prepare(conn, insert_query)

for index, row in df.iterrows():
    location = row['Location']
    timestamp = row['Timestamp']
    c1 = row['1.0μｍ']
    c3 = row['3.0μｍ']
    c5 = row['5.0μｍ']
    c10 = row['10.0μｍ']
    c15 = row['15.0μｍ']
    c20 = row['20.0μｍ']
    c25 = row['25.0μｍ']
    c50 = row['50.0μｍ']
    
    if ibm_db.execute(stmt, (location, timestamp, c1, c3, c5, c10, c15, c20, c25, c50)):
        print(f"Row {index + 1} inserted successfully")
    else:
        print(f"Error inserting row {index + 1}: {ibm_db.stmt_errormsg()}")
# Out:
# Row 1 inserted successfully
# Row 2 inserted successfully
# Row 3 inserted successfully
# Row 4 inserted successfully
# Row 5 inserted successfully
# Row 6 inserted successfully
# Row 7 inserted successfully
# Row 8 inserted successfully
# Row 9 inserted successfully
# Row 10 inserted successfully
# Row 11 inserted successfully
# Row 12 inserted successfully
# Row 13 inserted successfully
# Row 14 inserted successfully
# Row 15 inserted successfully
# Row 16 inserted successfully
# Row 17 inserted successfully
# Row 18 inserted successfully
# Row 19 inserted successfully
# Row 20 inserted successfully
# Row 21 inserted successfully
# Row 22 inserted successfully
# Row 23 inserted successfully
# Row 24 inserted successfully
# Row 25 inserted successfully
# Row 26 inserted successfully
# Row 27 inserted successfully
# Row 28 inserted successfully
# Row 29 inserted successfully
# Row 30 inserted successfully
# Row 31 inserted successfully
# Row 32 inserted successfully
# Row 33 inserted successfully
# Row 34 inserted successfully
# Row 35 inserted successfully
# Row 36 inserted successfully
# Row 37 inserted successfully
# Row 38 inserted successfully
# Row 39 inserted successfully
# Row 40 inserted successfully
# Row 41 inserted successfully
# Row 42 inserted successfully
# Row 43 inserted successfully
# Row 44 inserted successfully
# Row 45 inserted successfully
# Row 46 inserted successfully
# Row 47 inserted successfully
# Row 48 inserted successfully
# Row 49 inserted successfully
# Row 50 inserted successfully
# Row 51 inserted successfully
# Row 52 inserted successfully
# Row 53 inserted successfully
# Row 54 inserted successfully
# Row 55 inserted successfully
# Row 56 inserted successfully
# Row 57 inserted successfully
# Row 58 inserted successfully
# Row 59 inserted successfully
# Row 60 inserted successfully
# Row 61 inserted successfully
# Row 62 inserted successfully
# Row 63 inserted successfully
# Row 64 inserted successfully
# Row 65 inserted successfully
# Row 66 inserted successfully
# Row 67 inserted successfully
# Row 68 inserted successfully
# Row 69 inserted successfully
# Row 70 inserted successfully
# Row 71 inserted successfully
# Row 72 inserted successfully
# Row 73 inserted successfully
# Row 74 inserted successfully
# Row 75 inserted successfully
# Row 76 inserted successfully
# Row 77 inserted successfully
# Row 78 inserted successfully
# Row 79 inserted successfully
# Row 80 inserted successfully
# Row 81 inserted successfully
# Row 82 inserted successfully
# Row 83 inserted successfully
# Row 84 inserted successfully
# Row 85 inserted successfully
# Row 86 inserted successfully
# Row 87 inserted successfully
# Row 88 inserted successfully
# Row 89 inserted successfully
# Row 90 inserted successfully
# Row 91 inserted successfully
# Row 92 inserted successfully
# Row 93 inserted successfully
# Row 94 inserted successfully
# Row 95 inserted successfully
# Row 96 inserted successfully
# Row 97 inserted successfully
# Row 98 inserted successfully
# Row 99 inserted successfully
# Row 100 inserted successfully
# Row 101 inserted successfully
# Row 102 inserted successfully
# Row 103 inserted successfully
# Row 104 inserted successfully
# Row 105 inserted successfully
# Row 106 inserted successfully
# Row 107 inserted successfully
# Row 108 inserted successfully
# Row 109 inserted successfully
# Row 110 inserted successfully
# Row 111 inserted successfully
# Row 112 inserted successfully
# Row 113 inserted successfully
# Row 114 inserted successfully
# Row 115 inserted successfully
# Row 116 inserted successfully
# Row 117 inserted successfully
# Row 118 inserted successfully
# Row 119 inserted successfully
# Row 120 inserted successfully
# Row 121 inserted successfully
# Row 122 inserted successfully
# Row 123 inserted successfully
# Row 124 inserted successfully
# Row 125 inserted successfully
# Row 126 inserted successfully
# Row 127 inserted successfully
# Row 128 inserted successfully
# Row 129 inserted successfully
# Row 130 inserted successfully
# Row 131 inserted successfully
# Row 132 inserted successfully
# Row 133 inserted successfully
# Row 134 inserted successfully
# Row 135 inserted successfully
# Row 136 inserted successfully
# Row 137 inserted successfully
# Row 138 inserted successfully
# Row 139 inserted successfully
# Row 140 inserted successfully
# Row 141 inserted successfully
# Row 142 inserted successfully
# Row 143 inserted successfully
# Row 144 inserted successfully
# Row 145 inserted successfully
# Row 146 inserted successfully
# Row 147 inserted successfully
# Row 148 inserted successfully
# Row 149 inserted successfully
# Row 150 inserted successfully
# Row 151 inserted successfully
# Row 152 inserted successfully
# Row 153 inserted successfully
# Row 154 inserted successfully
# Row 155 inserted successfully
# Row 156 inserted successfully
# Row 157 inserted successfully
# Row 158 inserted successfully
# Row 159 inserted successfully
# Row 160 inserted successfully
# Row 161 inserted successfully
# Row 162 inserted successfully
# Row 163 inserted successfully
# Row 164 inserted successfully
# Row 165 inserted successfully
# Row 166 inserted successfully
# Row 167 inserted successfully
# Row 168 inserted successfully
# Row 169 inserted successfully
# Row 170 inserted successfully
# Row 171 inserted successfully
# Row 172 inserted successfully
# Row 173 inserted successfully
# Row 174 inserted successfully
# Row 175 inserted successfully
# Row 176 inserted successfully
# Row 177 inserted successfully
# Row 178 inserted successfully
# Row 179 inserted successfully
# Row 180 inserted successfully
# Row 181 inserted successfully
# Row 182 inserted successfully
# Row 183 inserted successfully
# Row 184 inserted successfully
# Row 185 inserted successfully
# Row 186 inserted successfully
# Row 187 inserted successfully
# Row 188 inserted successfully
# Row 189 inserted successfully
# Row 190 inserted successfully
# Row 191 inserted successfully
# Row 192 inserted successfully
# Row 193 inserted successfully
# Row 194 inserted successfully
# Row 195 inserted successfully
# Row 196 inserted successfully
# Row 197 inserted successfully
# Row 198 inserted successfully
# Row 199 inserted successfully
# Row 200 inserted successfully
# Row 201 inserted successfully
# Row 202 inserted successfully
# Row 203 inserted successfully
# Row 204 inserted successfully
# Row 205 inserted successfully
# Row 206 inserted successfully
# Row 207 inserted successfully
# Row 208 inserted successfully
# Row 209 inserted successfully
# Row 210 inserted successfully
# Row 211 inserted successfully
# Row 212 inserted successfully
# Row 213 inserted successfully
# Row 214 inserted successfully
# Row 215 inserted successfully
# Row 216 inserted successfully
# Row 217 inserted successfully
# Row 218 inserted successfully
# Row 219 inserted successfully
# Row 220 inserted successfully
# Row 221 inserted successfully
# Row 222 inserted successfully
# Row 223 inserted successfully
# Row 224 inserted successfully
# Row 225 inserted successfully
# Row 226 inserted successfully
# Row 227 inserted successfully
# Row 228 inserted successfully
# Row 229 inserted successfully
# Row 230 inserted successfully
# Row 231 inserted successfully
# Row 232 inserted successfully
# Row 233 inserted successfully
# Row 234 inserted successfully
# Row 235 inserted successfully
# Row 236 inserted successfully
# Row 237 inserted successfully
# Row 238 inserted successfully
# Row 239 inserted successfully
# Row 240 inserted successfully
# Row 241 inserted successfully
# Row 242 inserted successfully
# Row 243 inserted successfully
# Row 244 inserted successfully
# Row 245 inserted successfully
# Row 246 inserted successfully
# Row 247 inserted successfully
# Row 248 inserted successfully
# Row 249 inserted successfully
# Row 250 inserted successfully
# Row 251 inserted successfully
# Row 252 inserted successfully
# Row 253 inserted successfully
# Row 254 inserted successfully
# Row 255 inserted successfully
# Row 256 inserted successfully
# Row 257 inserted successfully
# Row 258 inserted successfully
# Row 259 inserted successfully
# Row 260 inserted successfully
# Row 261 inserted successfully
# Row 262 inserted successfully
# Row 263 inserted successfully
# Row 264 inserted successfully
# Row 265 inserted successfully
# Row 266 inserted successfully
# Row 267 inserted successfully
# Row 268 inserted successfully
# Row 269 inserted successfully
# Row 270 inserted successfully
# Row 271 inserted successfully
# Row 272 inserted successfully
# Row 273 inserted successfully
# Row 274 inserted successfully
# Row 275 inserted successfully
# Row 276 inserted successfully
# Row 277 inserted successfully
# Row 278 inserted successfully
# Row 279 inserted successfully
# Row 280 inserted successfully
# Row 281 inserted successfully
# Row 282 inserted successfully
# Row 283 inserted successfully
# Row 284 inserted successfully
# Row 285 inserted successfully
# Row 286 inserted successfully
# Row 287 inserted successfully
# Row 288 inserted successfully
# Row 289 inserted successfully
# Row 290 inserted successfully
# Row 291 inserted successfully
# Row 292 inserted successfully
# Row 293 inserted successfully
# Row 294 inserted successfully
# Row 295 inserted successfully
# Row 296 inserted successfully
# Row 297 inserted successfully
# Row 298 inserted successfully
# Row 299 inserted successfully
# Row 300 inserted successfully
# Row 301 inserted successfully
# Row 302 inserted successfully
# Row 303 inserted successfully
# Row 304 inserted successfully
# Row 305 inserted successfully
# Row 306 inserted successfully
# Row 307 inserted successfully
# Row 308 inserted successfully
# Row 309 inserted successfully
# Row 310 inserted successfully
# Row 311 inserted successfully
# Row 312 inserted successfully
# Row 313 inserted successfully
# Row 314 inserted successfully
# Row 315 inserted successfully
# Row 316 inserted successfully
# Row 317 inserted successfully
# Row 318 inserted successfully
# Row 319 inserted successfully
# Row 320 inserted successfully
# Row 321 inserted successfully
# Row 322 inserted successfully
# Row 323 inserted successfully
# Row 324 inserted successfully
# Row 325 inserted successfully
# Row 326 inserted successfully
# Row 327 inserted successfully
# Row 328 inserted successfully
# Row 329 inserted successfully
# Row 330 inserted successfully
# Row 331 inserted successfully
# Row 332 inserted successfully
# Row 333 inserted successfully
# Row 334 inserted successfully
# Row 335 inserted successfully
# Row 336 inserted successfully
# Row 337 inserted successfully
# Row 338 inserted successfully
# Row 339 inserted successfully
# Row 340 inserted successfully
# Row 341 inserted successfully
# Row 342 inserted successfully
# Row 343 inserted successfully
# Row 344 inserted successfully
# Row 345 inserted successfully
# Row 346 inserted successfully
# Row 347 inserted successfully
# Row 348 inserted successfully
# Row 349 inserted successfully
# Row 350 inserted successfully
# Row 351 inserted successfully
# Row 352 inserted successfully
# Row 353 inserted successfully
# Row 354 inserted successfully
# Row 355 inserted successfully
# Row 356 inserted successfully
# Row 357 inserted successfully
# Row 358 inserted successfully
# Row 359 inserted successfully
# Row 360 inserted successfully
# Row 361 inserted successfully
# Row 362 inserted successfully
# Row 363 inserted successfully
# Row 364 inserted successfully
# Row 365 inserted successfully
# Row 366 inserted successfully
# Row 367 inserted successfully
# Row 368 inserted successfully
# Row 369 inserted successfully
# Row 370 inserted successfully
# Row 371 inserted successfully
# Row 372 inserted successfully
# Row 373 inserted successfully
# Row 374 inserted successfully
# Row 375 inserted successfully
# Row 376 inserted successfully
# Row 377 inserted successfully
# Row 378 inserted successfully
# Row 379 inserted successfully
# Row 380 inserted successfully
# Row 381 inserted successfully
# Row 382 inserted successfully
# Row 383 inserted successfully
# Row 384 inserted successfully
# Row 385 inserted successfully
# Row 386 inserted successfully
# Row 387 inserted successfully
# Row 388 inserted successfully
# Row 389 inserted successfully
# Row 390 inserted successfully
# Row 391 inserted successfully
# Row 392 inserted successfully
# Row 393 inserted successfully
# Row 394 inserted successfully
# Row 395 inserted successfully
# Row 396 inserted successfully
# Row 397 inserted successfully
# Row 398 inserted successfully
# Row 399 inserted successfully
# Row 400 inserted successfully
# Row 401 inserted successfully
# Row 402 inserted successfully
# Row 403 inserted successfully
# Row 404 inserted successfully
# Row 405 inserted successfully
# Row 406 inserted successfully
# Row 407 inserted successfully
# Row 408 inserted successfully
# Row 409 inserted successfully
# Row 410 inserted successfully
# Row 411 inserted successfully
# Row 412 inserted successfully
# Row 413 inserted successfully
# Row 414 inserted successfully
# Row 415 inserted successfully
# Row 416 inserted successfully
# Row 417 inserted successfully
# Row 418 inserted successfully
# Row 419 inserted successfully
# Row 420 inserted successfully
# Row 421 inserted successfully
# Row 422 inserted successfully
# Row 423 inserted successfully
# Row 424 inserted successfully
# Row 425 inserted successfully
# Row 426 inserted successfully
# Row 427 inserted successfully
# Row 428 inserted successfully
# Row 429 inserted successfully
# Row 430 inserted successfully
# Row 431 inserted successfully
# Row 432 inserted successfully
# Row 433 inserted successfully
# Row 434 inserted successfully
# Row 435 inserted successfully
# Row 436 inserted successfully
# Row 437 inserted successfully
# Row 438 inserted successfully
# Row 439 inserted successfully
# Row 440 inserted successfully
# Row 441 inserted successfully
# Row 442 inserted successfully
# Row 443 inserted successfully
# Row 444 inserted successfully
# Row 445 inserted successfully
# Row 446 inserted successfully
# Row 447 inserted successfully
# Row 448 inserted successfully
# Row 449 inserted successfully
# Row 450 inserted successfully
# Row 451 inserted successfully
# Row 452 inserted successfully
# Row 453 inserted successfully
# Row 454 inserted successfully
# Row 455 inserted successfully
# Row 456 inserted successfully
# Row 457 inserted successfully
# Row 458 inserted successfully
# Row 459 inserted successfully
# Row 460 inserted successfully
# Row 461 inserted successfully
# Row 462 inserted successfully
# Row 463 inserted successfully
# Row 464 inserted successfully
# Row 465 inserted successfully
# Row 466 inserted successfully
# Row 467 inserted successfully
# Row 468 inserted successfully
# Row 469 inserted successfully
# Row 470 inserted successfully
# Row 471 inserted successfully
# Row 472 inserted successfully
# Row 473 inserted successfully
# Row 474 inserted successfully
# Row 475 inserted successfully
# Row 476 inserted successfully
# Row 477 inserted successfully
# Row 478 inserted successfully
# Row 479 inserted successfully
# Row 480 inserted successfully
# Row 481 inserted successfully
# Row 482 inserted successfully
# Row 483 inserted successfully
# Row 484 inserted successfully
# Row 485 inserted successfully
# Row 486 inserted successfully
# Row 487 inserted successfully
# Row 488 inserted successfully
# Row 489 inserted successfully
# Row 490 inserted successfully
# Row 491 inserted successfully
# Row 492 inserted successfully
# Row 493 inserted successfully
# Row 494 inserted successfully
# Row 495 inserted successfully
# Row 496 inserted successfully
# Row 497 inserted successfully
# Row 498 inserted successfully
# Row 499 inserted successfully
# Row 500 inserted successfully
# Row 501 inserted successfully
# Row 502 inserted successfully
# Row 503 inserted successfully
# Row 504 inserted successfully
# Row 505 inserted successfully
# Row 506 inserted successfully
# Row 507 inserted successfully
# Row 508 inserted successfully
# Row 509 inserted successfully
# Row 510 inserted successfully
# Row 511 inserted successfully
# Row 512 inserted successfully
# Row 513 inserted successfully
# Row 514 inserted successfully
# Row 515 inserted successfully
# Row 516 inserted successfully
# Row 517 inserted successfully
# Row 518 inserted successfully
# Row 519 inserted successfully
# Row 520 inserted successfully
# Row 521 inserted successfully
# Row 522 inserted successfully
# Row 523 inserted successfully
# Row 524 inserted successfully
# Row 525 inserted successfully
# Row 526 inserted successfully
# Row 527 inserted successfully
# Row 528 inserted successfully
# Row 529 inserted successfully
# Row 530 inserted successfully
# Row 531 inserted successfully
# Row 532 inserted successfully
# Row 533 inserted successfully
# Row 534 inserted successfully
# Row 535 inserted successfully
# Row 536 inserted successfully
# Row 537 inserted successfully
# Row 538 inserted successfully
# Row 539 inserted successfully
# Row 540 inserted successfully
# Row 541 inserted successfully
# Row 542 inserted successfully
# Row 543 inserted successfully
# Row 544 inserted successfully
# Row 545 inserted successfully
# Row 546 inserted successfully
# Row 547 inserted successfully
# Row 548 inserted successfully
# Row 549 inserted successfully
# Row 550 inserted successfully
# Row 551 inserted successfully
# Row 552 inserted successfully
# Row 553 inserted successfully
# Row 554 inserted successfully
# Row 555 inserted successfully
# Row 556 inserted successfully
# Row 557 inserted successfully
# Row 558 inserted successfully
# Row 559 inserted successfully
# Row 560 inserted successfully
# Row 561 inserted successfully
# Row 562 inserted successfully
# Row 563 inserted successfully
# Row 564 inserted successfully
# Row 565 inserted successfully
# Row 566 inserted successfully
# Row 567 inserted successfully
# Row 568 inserted successfully
# Row 569 inserted successfully
# Row 570 inserted successfully
# Row 571 inserted successfully
# Row 572 inserted successfully
# Row 573 inserted successfully
# Row 574 inserted successfully
# Row 575 inserted successfully
# Row 576 inserted successfully
# Row 577 inserted successfully
# Row 578 inserted successfully
# Row 579 inserted successfully
# Row 580 inserted successfully
# Row 581 inserted successfully
# Row 582 inserted successfully
# Row 583 inserted successfully
# Row 584 inserted successfully
# Row 585 inserted successfully
# Row 586 inserted successfully
# Row 587 inserted successfully
# Row 588 inserted successfully
# Row 589 inserted successfully
# Row 590 inserted successfully
# Row 591 inserted successfully
# Row 592 inserted successfully
# Row 593 inserted successfully
# Row 594 inserted successfully
# Row 595 inserted successfully
# Row 596 inserted successfully
# Row 597 inserted successfully
# Row 598 inserted successfully
# Row 599 inserted successfully
# Row 600 inserted successfully
# Row 601 inserted successfully
# Row 602 inserted successfully
# Row 603 inserted successfully
# Row 604 inserted successfully
# Row 605 inserted successfully
# Row 606 inserted successfully
# Row 607 inserted successfully
# Row 608 inserted successfully
# Row 609 inserted successfully
# Row 610 inserted successfully
# Row 611 inserted successfully
# Row 612 inserted successfully
# Row 613 inserted successfully
# Row 614 inserted successfully
# Row 615 inserted successfully
# Row 616 inserted successfully
# Row 617 inserted successfully
# Row 618 inserted successfully
# Row 619 inserted successfully
# Row 620 inserted successfully
# Row 621 inserted successfully
# Row 622 inserted successfully
# Row 623 inserted successfully
# Row 624 inserted successfully
# Row 625 inserted successfully
# Row 626 inserted successfully
# Row 627 inserted successfully
# Row 628 inserted successfully
# Row 629 inserted successfully
# Row 630 inserted successfully
# Row 631 inserted successfully
# Row 632 inserted successfully
# Row 633 inserted successfully
# Row 634 inserted successfully
# Row 635 inserted successfully
# Row 636 inserted successfully
# Row 637 inserted successfully
# Row 638 inserted successfully
# Row 639 inserted successfully
# Row 640 inserted successfully
# Row 641 inserted successfully
# Row 642 inserted successfully
# Row 643 inserted successfully
# Row 644 inserted successfully
# Row 645 inserted successfully
# Row 646 inserted successfully
# Row 647 inserted successfully
# Row 648 inserted successfully
# Row 649 inserted successfully
# Row 650 inserted successfully
# Row 651 inserted successfully
# Row 652 inserted successfully
# Row 653 inserted successfully
# Row 654 inserted successfully
# Row 655 inserted successfully
# Row 656 inserted successfully
# Row 657 inserted successfully
# Row 658 inserted successfully
# Row 659 inserted successfully
# Row 660 inserted successfully
# Row 661 inserted successfully
# Row 662 inserted successfully
# Row 663 inserted successfully
# Row 664 inserted successfully
# Row 665 inserted successfully
# Row 666 inserted successfully
# Row 667 inserted successfully
# Row 668 inserted successfully
# Row 669 inserted successfully
# Row 670 inserted successfully
# Row 671 inserted successfully
# Row 672 inserted successfully
# Row 673 inserted successfully
# Row 674 inserted successfully
# Row 675 inserted successfully
# Row 676 inserted successfully
# Row 677 inserted successfully
# Row 678 inserted successfully
# Row 679 inserted successfully
# Row 680 inserted successfully
# Row 681 inserted successfully
# Row 682 inserted successfully
# Row 683 inserted successfully
# Row 684 inserted successfully
# Row 685 inserted successfully
# Row 686 inserted successfully
# Row 687 inserted successfully
# Row 688 inserted successfully
# Row 689 inserted successfully
# Row 690 inserted successfully
# Row 691 inserted successfully
# Row 692 inserted successfully
# Row 693 inserted successfully
# Row 694 inserted successfully
# Row 695 inserted successfully
# Row 696 inserted successfully
# Row 697 inserted successfully
# Row 698 inserted successfully
# Row 699 inserted successfully
# Row 700 inserted successfully
# Row 701 inserted successfully
# Row 702 inserted successfully
# Row 703 inserted successfully
# Row 704 inserted successfully
# Row 705 inserted successfully
# Row 706 inserted successfully
# Row 707 inserted successfully
# Row 708 inserted successfully
# Row 709 inserted successfully
# Row 710 inserted successfully
# Row 711 inserted successfully
# Row 712 inserted successfully
# Row 713 inserted successfully
# Row 714 inserted successfully
# Row 715 inserted successfully
# Row 716 inserted successfully
# Row 717 inserted successfully
# Row 718 inserted successfully
# Row 719 inserted successfully
# Row 720 inserted successfully
# Row 721 inserted successfully
# Row 722 inserted successfully
# Row 723 inserted successfully
# Row 724 inserted successfully
# Row 725 inserted successfully
# Row 726 inserted successfully
# Row 727 inserted successfully
# Row 728 inserted successfully
# Row 729 inserted successfully
# Row 730 inserted successfully
# Row 731 inserted successfully
# Row 732 inserted successfully
# Row 733 inserted successfully
# Row 734 inserted successfully
# Row 735 inserted successfully
# Row 736 inserted successfully
# Row 737 inserted successfully
# Row 738 inserted successfully
# Row 739 inserted successfully
# Row 740 inserted successfully
# Row 741 inserted successfully
# Row 742 inserted successfully
# Row 743 inserted successfully
# Row 744 inserted successfully
# Row 745 inserted successfully
# Row 746 inserted successfully
# Row 747 inserted successfully
# Row 748 inserted successfully
# Row 749 inserted successfully
# Row 750 inserted successfully
# Row 751 inserted successfully
# Row 752 inserted successfully
# Row 753 inserted successfully
# Row 754 inserted successfully
# Row 755 inserted successfully
# Row 756 inserted successfully
# Row 757 inserted successfully
# Row 758 inserted successfully
# Row 759 inserted successfully
# Row 760 inserted successfully
# Row 761 inserted successfully
# Row 762 inserted successfully
# Row 763 inserted successfully
# Row 764 inserted successfully
# Row 765 inserted successfully
# Row 766 inserted successfully
# Row 767 inserted successfully
# Row 768 inserted successfully
# Row 769 inserted successfully
# Row 770 inserted successfully
# Row 771 inserted successfully
# Row 772 inserted successfully
# Row 773 inserted successfully
# Row 774 inserted successfully
# Row 775 inserted successfully
# Row 776 inserted successfully
# Row 777 inserted successfully
# Row 778 inserted successfully
# Row 779 inserted successfully
# Row 780 inserted successfully
# Row 781 inserted successfully
# Row 782 inserted successfully
# Row 783 inserted successfully
# Row 784 inserted successfully
# Row 785 inserted successfully
# Row 786 inserted successfully
# Row 787 inserted successfully
# Row 788 inserted successfully
# Row 789 inserted successfully
# Row 790 inserted successfully
# Row 791 inserted successfully
# Row 792 inserted successfully
# Row 793 inserted successfully
# Row 794 inserted successfully
# Row 795 inserted successfully
# Row 796 inserted successfully
# Row 797 inserted successfully
# Row 798 inserted successfully
# Row 799 inserted successfully
# Row 800 inserted successfully
# Row 801 inserted successfully
# Row 802 inserted successfully
# Row 803 inserted successfully
# Row 804 inserted successfully
# Row 805 inserted successfully
# Row 806 inserted successfully
# Row 807 inserted successfully
# Row 808 inserted successfully
# Row 809 inserted successfully
# Row 810 inserted successfully
# Row 811 inserted successfully
# Row 812 inserted successfully
# Row 813 inserted successfully
# Row 814 inserted successfully
# Row 815 inserted successfully
# Row 816 inserted successfully
# Row 817 inserted successfully
# Row 818 inserted successfully
# Row 819 inserted successfully
# Row 820 inserted successfully
# Row 821 inserted successfully
# Row 822 inserted successfully
# Row 823 inserted successfully
# Row 824 inserted successfully
# Row 825 inserted successfully
# Row 826 inserted successfully
# Row 827 inserted successfully
# Row 828 inserted successfully
# Row 829 inserted successfully
# Row 830 inserted successfully
# Row 831 inserted successfully
# Row 832 inserted successfully
# Row 833 inserted successfully
# Row 834 inserted successfully
# Row 835 inserted successfully
# Row 836 inserted successfully
# Row 837 inserted successfully
# Row 838 inserted successfully
# Row 839 inserted successfully
# Row 840 inserted successfully
# Row 841 inserted successfully
# Row 842 inserted successfully
# Row 843 inserted successfully
# Row 844 inserted successfully
# Row 845 inserted successfully
# Row 846 inserted successfully
# Row 847 inserted successfully
# Row 848 inserted successfully
# Row 849 inserted successfully
# Row 850 inserted successfully
# Row 851 inserted successfully
# Row 852 inserted successfully
# Row 853 inserted successfully
# Row 854 inserted successfully
# Row 855 inserted successfully
# Row 856 inserted successfully
# Row 857 inserted successfully
# Row 858 inserted successfully
# Row 859 inserted successfully
# Row 860 inserted successfully
# Row 861 inserted successfully
# Row 862 inserted successfully
# Row 863 inserted successfully
# Row 864 inserted successfully
# Row 865 inserted successfully
# Row 866 inserted successfully
# Row 867 inserted successfully
# Row 868 inserted successfully
# Row 869 inserted successfully
# Row 870 inserted successfully
# Row 871 inserted successfully
# Row 872 inserted successfully
# Row 873 inserted successfully
# Row 874 inserted successfully
# Row 875 inserted successfully
# Row 876 inserted successfully
# Row 877 inserted successfully
# Row 878 inserted successfully
# Row 879 inserted successfully
# Row 880 inserted successfully
# Row 881 inserted successfully
# Row 882 inserted successfully
# Row 883 inserted successfully
# Row 884 inserted successfully
# Row 885 inserted successfully
# Row 886 inserted successfully
# Row 887 inserted successfully
# Row 888 inserted successfully
# Row 889 inserted successfully
# Row 890 inserted successfully
# Row 891 inserted successfully
# Row 892 inserted successfully
# Row 893 inserted successfully
# Row 894 inserted successfully
# Row 895 inserted successfully
# Row 896 inserted successfully
# Row 897 inserted successfully
# Row 898 inserted successfully
# Row 899 inserted successfully
# Row 900 inserted successfully
# Row 901 inserted successfully
# Row 902 inserted successfully
# Row 903 inserted successfully
# Row 904 inserted successfully
# Row 905 inserted successfully
# Row 906 inserted successfully
# Row 907 inserted successfully
# Row 908 inserted successfully
# Row 909 inserted successfully
# Row 910 inserted successfully
# Row 911 inserted successfully
# Row 912 inserted successfully
# Row 913 inserted successfully
# Row 914 inserted successfully
# Row 915 inserted successfully
# Row 916 inserted successfully
# Row 917 inserted successfully
# Row 918 inserted successfully
# Row 919 inserted successfully
# Row 920 inserted successfully
# Row 921 inserted successfully
# Row 922 inserted successfully
# Row 923 inserted successfully
# Row 924 inserted successfully
# Row 925 inserted successfully
# Row 926 inserted successfully
# Row 927 inserted successfully
# Row 928 inserted successfully
# Row 929 inserted successfully
# Row 930 inserted successfully
# Row 931 inserted successfully
# Row 932 inserted successfully
# Row 933 inserted successfully
# Row 934 inserted successfully
# Row 935 inserted successfully
# Row 936 inserted successfully
# Row 937 inserted successfully
# Row 938 inserted successfully
# Row 939 inserted successfully
# Row 940 inserted successfully
# Row 941 inserted successfully
# Row 942 inserted successfully
# Row 943 inserted successfully
# Row 944 inserted successfully
# Row 945 inserted successfully
# Row 946 inserted successfully
# Row 947 inserted successfully
# Row 948 inserted successfully
# Row 949 inserted successfully
# Row 950 inserted successfully
# Row 951 inserted successfully
# Row 952 inserted successfully
# Row 953 inserted successfully
# Row 954 inserted successfully
# Row 955 inserted successfully
# Row 956 inserted successfully
# Row 957 inserted successfully
# Row 958 inserted successfully
# Row 959 inserted successfully
# Row 960 inserted successfully
# Row 961 inserted successfully
# Row 962 inserted successfully
# Row 963 inserted successfully
# Row 964 inserted successfully
# Row 965 inserted successfully
# Row 966 inserted successfully
# Row 967 inserted successfully
# Row 968 inserted successfully
# Row 969 inserted successfully
# Row 970 inserted successfully
# Row 971 inserted successfully
# Row 972 inserted successfully
# Row 973 inserted successfully
# Row 974 inserted successfully
# Row 975 inserted successfully
# Row 976 inserted successfully
# Row 977 inserted successfully
# Row 978 inserted successfully
# Row 979 inserted successfully
# Row 980 inserted successfully
# Row 981 inserted successfully
# Row 982 inserted successfully
# Row 983 inserted successfully
# Row 984 inserted successfully
# Row 985 inserted successfully
# Row 986 inserted successfully
# Row 987 inserted successfully
# Row 988 inserted successfully
# Row 989 inserted successfully
# Row 990 inserted successfully
# Row 991 inserted successfully
# Row 992 inserted successfully
# Row 993 inserted successfully
# Row 994 inserted successfully
# Row 995 inserted successfully
# Row 996 inserted successfully
# Row 997 inserted successfully
# Row 998 inserted successfully
# Row 999 inserted successfully
# Row 1000 inserted successfully
# Row 1001 inserted successfully
# Row 1002 inserted successfully
# Row 1003 inserted successfully
# Row 1004 inserted successfully
# Row 1005 inserted successfully
# Row 1006 inserted successfully
# Row 1007 inserted successfully
# Row 1008 inserted successfully
# Row 1009 inserted successfully
# Row 1010 inserted successfully
# Row 1011 inserted successfully
# Row 1012 inserted successfully
# Row 1013 inserted successfully
# Row 1014 inserted successfully
# Row 1015 inserted successfully
# Row 1016 inserted successfully
# Row 1017 inserted successfully
# Row 1018 inserted successfully
# Row 1019 inserted successfully
# Row 1020 inserted successfully
# Row 1021 inserted successfully
# Row 1022 inserted successfully
# Row 1023 inserted successfully
# Row 1024 inserted successfully
# Row 1025 inserted successfully
# Row 1026 inserted successfully
# Row 1027 inserted successfully
# Row 1028 inserted successfully
# Row 1029 inserted successfully
# Row 1030 inserted successfully
# Row 1031 inserted successfully
# Row 1032 inserted successfully
# Row 1033 inserted successfully
# Row 1034 inserted successfully
# Row 1035 inserted successfully
# Row 1036 inserted successfully
# Row 1037 inserted successfully
# Row 1038 inserted successfully
# Row 1039 inserted successfully
# Row 1040 inserted successfully
# Row 1041 inserted successfully
# Row 1042 inserted successfully
# Row 1043 inserted successfully
# Row 1044 inserted successfully
# Row 1045 inserted successfully
# Row 1046 inserted successfully
# Row 1047 inserted successfully
# Row 1048 inserted successfully
# Row 1049 inserted successfully
# Row 1050 inserted successfully
# Row 1051 inserted successfully
# Row 1052 inserted successfully
# Row 1053 inserted successfully
# Row 1054 inserted successfully
# Row 1055 inserted successfully
# Row 1056 inserted successfully
# Row 1057 inserted successfully
# Row 1058 inserted successfully
# Row 1059 inserted successfully
# Row 1060 inserted successfully
# Row 1061 inserted successfully
# Row 1062 inserted successfully
# Row 1063 inserted successfully
# Row 1064 inserted successfully
# Row 1065 inserted successfully
# Row 1066 inserted successfully
# Row 1067 inserted successfully
# Row 1068 inserted successfully
# Row 1069 inserted successfully
# Row 1070 inserted successfully
# Row 1071 inserted successfully
# Row 1072 inserted successfully
# Row 1073 inserted successfully
# Row 1074 inserted successfully
# Row 1075 inserted successfully
# Row 1076 inserted successfully
# Row 1077 inserted successfully
# Row 1078 inserted successfully
# Row 1079 inserted successfully
# Row 1080 inserted successfully
# Row 1081 inserted successfully
# Row 1082 inserted successfully
# Row 1083 inserted successfully
# Row 1084 inserted successfully
# Row 1085 inserted successfully
# Row 1086 inserted successfully
# Row 1087 inserted successfully
# Row 1088 inserted successfully
# Row 1089 inserted successfully
# Row 1090 inserted successfully
# Row 1091 inserted successfully
# Row 1092 inserted successfully
# Row 1093 inserted successfully
# Row 1094 inserted successfully
# Row 1095 inserted successfully
# Row 1096 inserted successfully
# Row 1097 inserted successfully
# Row 1098 inserted successfully
# Row 1099 inserted successfully
# Row 1100 inserted successfully
# Row 1101 inserted successfully
# Row 1102 inserted successfully
# Row 1103 inserted successfully
# Row 1104 inserted successfully
# Row 1105 inserted successfully
# Row 1106 inserted successfully
# Row 1107 inserted successfully
# Row 1108 inserted successfully
# Row 1109 inserted successfully
# Row 1110 inserted successfully
# Row 1111 inserted successfully
# Row 1112 inserted successfully
# Row 1113 inserted successfully
# Row 1114 inserted successfully
# Row 1115 inserted successfully
# Row 1116 inserted successfully
# Row 1117 inserted successfully
# Row 1118 inserted successfully
# Row 1119 inserted successfully
# Row 1120 inserted successfully
# Row 1121 inserted successfully
# Row 1122 inserted successfully
# Row 1123 inserted successfully
# Row 1124 inserted successfully
# Row 1125 inserted successfully
# Row 1126 inserted successfully
# Row 1127 inserted successfully
# Row 1128 inserted successfully
# Row 1129 inserted successfully
# Row 1130 inserted successfully
# Row 1131 inserted successfully
# Row 1132 inserted successfully
# Row 1133 inserted successfully
# Row 1134 inserted successfully
# Row 1135 inserted successfully
# Row 1136 inserted successfully
# Row 1137 inserted successfully
# Row 1138 inserted successfully
# Row 1139 inserted successfully
# Row 1140 inserted successfully
# Row 1141 inserted successfully
# Row 1142 inserted successfully
# Row 1143 inserted successfully
# Row 1144 inserted successfully
# Row 1145 inserted successfully
# Row 1146 inserted successfully
# Row 1147 inserted successfully
# Row 1148 inserted successfully
# Row 1149 inserted successfully
# Row 1150 inserted successfully
# Row 1151 inserted successfully
# Row 1152 inserted successfully
# Row 1153 inserted successfully
# Row 1154 inserted successfully
# Row 1155 inserted successfully
# Row 1156 inserted successfully
# Row 1157 inserted successfully
# Row 1158 inserted successfully
# Row 1159 inserted successfully
# Row 1160 inserted successfully
# Row 1161 inserted successfully
# Row 1162 inserted successfully
# Row 1163 inserted successfully
# Row 1164 inserted successfully
# Row 1165 inserted successfully
# Row 1166 inserted successfully
# Row 1167 inserted successfully
# Row 1168 inserted successfully
# Row 1169 inserted successfully
# Row 1170 inserted successfully
# Row 1171 inserted successfully
# Row 1172 inserted successfully
# Row 1173 inserted successfully
# Row 1174 inserted successfully
# Row 1175 inserted successfully
# Row 1176 inserted successfully
# Row 1177 inserted successfully
# Row 1178 inserted successfully
# Row 1179 inserted successfully
# Row 1180 inserted successfully
# Row 1181 inserted successfully
# Row 1182 inserted successfully
# Row 1183 inserted successfully
# Row 1184 inserted successfully
# Row 1185 inserted successfully
# Row 1186 inserted successfully
# Row 1187 inserted successfully
# Row 1188 inserted successfully
# Row 1189 inserted successfully
# Row 1190 inserted successfully
# Row 1191 inserted successfully
# Row 1192 inserted successfully
# Row 1193 inserted successfully
# Row 1194 inserted successfully
# Row 1195 inserted successfully
# Row 1196 inserted successfully
# Row 1197 inserted successfully
# Row 1198 inserted successfully
# Row 1199 inserted successfully
# Row 1200 inserted successfully
# Row 1201 inserted successfully
# Row 1202 inserted successfully
# Row 1203 inserted successfully
# Row 1204 inserted successfully
# Row 1205 inserted successfully
# Row 1206 inserted successfully
# Row 1207 inserted successfully
# Row 1208 inserted successfully
# Row 1209 inserted successfully
# Row 1210 inserted successfully
# Row 1211 inserted successfully
# Row 1212 inserted successfully
# Row 1213 inserted successfully
# Row 1214 inserted successfully
# Row 1215 inserted successfully
# Row 1216 inserted successfully
# Row 1217 inserted successfully
# Row 1218 inserted successfully
# Row 1219 inserted successfully
# Row 1220 inserted successfully
# Row 1221 inserted successfully
# Row 1222 inserted successfully
# Row 1223 inserted successfully
# Row 1224 inserted successfully
# Row 1225 inserted successfully
# Row 1226 inserted successfully
# Row 1227 inserted successfully
# Row 1228 inserted successfully
# Row 1229 inserted successfully
# Row 1230 inserted successfully
# Row 1231 inserted successfully
# Row 1232 inserted successfully
# Row 1233 inserted successfully
# Row 1234 inserted successfully
# Row 1235 inserted successfully
# Row 1236 inserted successfully
# Row 1237 inserted successfully
# Row 1238 inserted successfully
# Row 1239 inserted successfully
# Row 1240 inserted successfully
# Row 1241 inserted successfully
# Row 1242 inserted successfully
# Row 1243 inserted successfully
# Row 1244 inserted successfully
# Row 1245 inserted successfully
# Row 1246 inserted successfully
# Row 1247 inserted successfully
# Row 1248 inserted successfully
# Row 1249 inserted successfully
# Row 1250 inserted successfully
# Row 1251 inserted successfully
# Row 1252 inserted successfully
# Row 1253 inserted successfully
# Row 1254 inserted successfully
# Row 1255 inserted successfully
# Row 1256 inserted successfully
# Row 1257 inserted successfully
# Row 1258 inserted successfully
# Row 1259 inserted successfully
# Row 1260 inserted successfully
# Row 1261 inserted successfully
# Row 1262 inserted successfully
# Row 1263 inserted successfully
# Row 1264 inserted successfully
# Row 1265 inserted successfully
# Row 1266 inserted successfully
# Row 1267 inserted successfully
# Row 1268 inserted successfully
# Row 1269 inserted successfully
# Row 1270 inserted successfully
# Row 1271 inserted successfully
# Row 1272 inserted successfully
# Row 1273 inserted successfully
# Row 1274 inserted successfully
# Row 1275 inserted successfully
# Row 1276 inserted successfully
# Row 1277 inserted successfully
# Row 1278 inserted successfully
# Row 1279 inserted successfully
# Row 1280 inserted successfully
# Row 1281 inserted successfully
# Row 1282 inserted successfully
# Row 1283 inserted successfully
# Row 1284 inserted successfully
# Row 1285 inserted successfully
# Row 1286 inserted successfully
# Row 1287 inserted successfully
# Row 1288 inserted successfully
# Row 1289 inserted successfully
# Row 1290 inserted successfully
# Row 1291 inserted successfully
# Row 1292 inserted successfully
# Row 1293 inserted successfully
# Row 1294 inserted successfully
# Row 1295 inserted successfully
# Row 1296 inserted successfully
# Row 1297 inserted successfully
# Row 1298 inserted successfully
# Row 1299 inserted successfully
# Row 1300 inserted successfully
# Row 1301 inserted successfully
# Row 1302 inserted successfully
# Row 1303 inserted successfully
# Row 1304 inserted successfully
# Row 1305 inserted successfully
# Row 1306 inserted successfully
# Row 1307 inserted successfully
# Row 1308 inserted successfully
# Row 1309 inserted successfully
# Row 1310 inserted successfully
# Row 1311 inserted successfully
# Row 1312 inserted successfully
# Row 1313 inserted successfully
# Row 1314 inserted successfully
# Row 1315 inserted successfully
# Row 1316 inserted successfully
# Row 1317 inserted successfully
# Row 1318 inserted successfully
# Row 1319 inserted successfully
# Row 1320 inserted successfully
# Row 1321 inserted successfully
# Row 1322 inserted successfully
# Row 1323 inserted successfully
# Row 1324 inserted successfully
# Row 1325 inserted successfully
# Row 1326 inserted successfully
# Row 1327 inserted successfully
# Row 1328 inserted successfully
# Row 1329 inserted successfully
# Row 1330 inserted successfully
# Row 1331 inserted successfully
# Row 1332 inserted successfully
# Row 1333 inserted successfully
# Row 1334 inserted successfully
# Row 1335 inserted successfully
# Row 1336 inserted successfully
# Row 1337 inserted successfully
# Row 1338 inserted successfully
# Row 1339 inserted successfully
# Row 1340 inserted successfully
# Row 1341 inserted successfully
# Row 1342 inserted successfully
# Row 1343 inserted successfully
# Row 1344 inserted successfully
# Row 1345 inserted successfully
# Row 1346 inserted successfully
# Row 1347 inserted successfully
# Row 1348 inserted successfully
# Row 1349 inserted successfully
# Row 1350 inserted successfully
# Row 1351 inserted successfully
# Row 1352 inserted successfully
# Row 1353 inserted successfully
# Row 1354 inserted successfully
# Row 1355 inserted successfully
# Row 1356 inserted successfully
# Row 1357 inserted successfully
# Row 1358 inserted successfully
# Row 1359 inserted successfully
# Row 1360 inserted successfully
# Row 1361 inserted successfully
# Row 1362 inserted successfully
# Row 1363 inserted successfully
# Row 1364 inserted successfully
# Row 1365 inserted successfully
# Row 1366 inserted successfully
# Row 1367 inserted successfully
# Row 1368 inserted successfully
# Row 1369 inserted successfully
# Row 1370 inserted successfully
# Row 1371 inserted successfully
# Row 1372 inserted successfully
# Row 1373 inserted successfully
# Row 1374 inserted successfully
# Row 1375 inserted successfully
# Row 1376 inserted successfully
# Row 1377 inserted successfully
# Row 1378 inserted successfully
# Row 1379 inserted successfully
# Row 1380 inserted successfully
# Row 1381 inserted successfully
# Row 1382 inserted successfully
# Row 1383 inserted successfully
# Row 1384 inserted successfully
# Row 1385 inserted successfully
# Row 1386 inserted successfully
# Row 1387 inserted successfully
# Row 1388 inserted successfully
# Row 1389 inserted successfully
# Row 1390 inserted successfully
# Row 1391 inserted successfully
# Row 1392 inserted successfully
# Row 1393 inserted successfully
# Row 1394 inserted successfully
# Row 1395 inserted successfully
# Row 1396 inserted successfully
# Row 1397 inserted successfully
# Row 1398 inserted successfully
# Row 1399 inserted successfully
# Row 1400 inserted successfully
# Row 1401 inserted successfully
# Row 1402 inserted successfully
# Row 1403 inserted successfully
# Row 1404 inserted successfully
# Row 1405 inserted successfully
# Row 1406 inserted successfully
# Row 1407 inserted successfully
# Row 1408 inserted successfully
# Row 1409 inserted successfully
# Row 1410 inserted successfully
# Row 1411 inserted successfully
# Row 1412 inserted successfully
# Row 1413 inserted successfully
# Row 1414 inserted successfully
# Row 1415 inserted successfully
# Row 1416 inserted successfully
# Row 1417 inserted successfully
# Row 1418 inserted successfully
# Row 1419 inserted successfully
# Row 1420 inserted successfully
# Row 1421 inserted successfully
# Row 1422 inserted successfully
# Row 1423 inserted successfully
# Row 1424 inserted successfully
# Row 1425 inserted successfully
# Row 1426 inserted successfully
# Row 1427 inserted successfully
# Row 1428 inserted successfully
# Row 1429 inserted successfully
# Row 1430 inserted successfully
# Row 1431 inserted successfully
# Row 1432 inserted successfully
# Row 1433 inserted successfully
# Row 1434 inserted successfully
# Row 1435 inserted successfully
# Row 1436 inserted successfully
# Row 1437 inserted successfully
# Row 1438 inserted successfully
# Row 1439 inserted successfully
# Row 1440 inserted successfully
# Row 1441 inserted successfully
# Row 1442 inserted successfully
# Row 1443 inserted successfully
# Row 1444 inserted successfully
# Row 1445 inserted successfully
# Row 1446 inserted successfully
# Row 1447 inserted successfully
# Row 1448 inserted successfully
# Row 1449 inserted successfully
# Row 1450 inserted successfully
# Row 1451 inserted successfully
# Row 1452 inserted successfully
# Row 1453 inserted successfully
# Row 1454 inserted successfully
# Row 1455 inserted successfully
# Row 1456 inserted successfully
# Row 1457 inserted successfully
# Row 1458 inserted successfully
# Row 1459 inserted successfully
# Row 1460 inserted successfully
# Row 1461 inserted successfully
# Row 1462 inserted successfully
# Row 1463 inserted successfully
# Row 1464 inserted successfully
# Row 1465 inserted successfully
# Row 1466 inserted successfully
# Row 1467 inserted successfully
# Row 1468 inserted successfully
# Row 1469 inserted successfully
# Row 1470 inserted successfully
# Row 1471 inserted successfully
# Row 1472 inserted successfully
# Row 1473 inserted successfully
# Row 1474 inserted successfully
# Row 1475 inserted successfully
# Row 1476 inserted successfully
# Row 1477 inserted successfully
# Row 1478 inserted successfully
# Row 1479 inserted successfully
# Row 1480 inserted successfully
# Row 1481 inserted successfully
# Row 1482 inserted successfully
# Row 1483 inserted successfully
# Row 1484 inserted successfully
# Row 1485 inserted successfully
# Row 1486 inserted successfully
# Row 1487 inserted successfully
# Row 1488 inserted successfully
# Row 1489 inserted successfully
# Row 1490 inserted successfully
# Row 1491 inserted successfully
# Row 1492 inserted successfully
# Row 1493 inserted successfully
# Row 1494 inserted successfully
# Row 1495 inserted successfully
# Row 1496 inserted successfully
# Row 1497 inserted successfully
# Row 1498 inserted successfully
# Row 1499 inserted successfully
# Row 1500 inserted successfully
# Row 1501 inserted successfully
# Row 1502 inserted successfully
# Row 1503 inserted successfully
# Row 1504 inserted successfully
# Row 1505 inserted successfully
# Row 1506 inserted successfully
# Row 1507 inserted successfully
# Row 1508 inserted successfully
# Row 1509 inserted successfully
# Row 1510 inserted successfully
# Row 1511 inserted successfully
# Row 1512 inserted successfully
# Row 1513 inserted successfully
# Row 1514 inserted successfully
# Row 1515 inserted successfully
# Row 1516 inserted successfully
# Row 1517 inserted successfully
# Row 1518 inserted successfully
# Row 1519 inserted successfully
# Row 1520 inserted successfully
# Row 1521 inserted successfully
# Row 1522 inserted successfully
# Row 1523 inserted successfully
# Row 1524 inserted successfully
# Row 1525 inserted successfully
# Row 1526 inserted successfully
# Row 1527 inserted successfully
# Row 1528 inserted successfully
# Row 1529 inserted successfully
# Row 1530 inserted successfully
# Row 1531 inserted successfully
# Row 1532 inserted successfully
# Row 1533 inserted successfully
# Row 1534 inserted successfully
# Row 1535 inserted successfully
# Row 1536 inserted successfully
# Row 1537 inserted successfully
# Row 1538 inserted successfully
# Row 1539 inserted successfully
# Row 1540 inserted successfully
# Row 1541 inserted successfully
# Row 1542 inserted successfully
# Row 1543 inserted successfully
# Row 1544 inserted successfully
# Row 1545 inserted successfully
# Row 1546 inserted successfully
# Row 1547 inserted successfully
# Row 1548 inserted successfully
# Row 1549 inserted successfully
# Row 1550 inserted successfully
# Row 1551 inserted successfully
# Row 1552 inserted successfully
# Row 1553 inserted successfully
# Row 1554 inserted successfully
# Row 1555 inserted successfully
# Row 1556 inserted successfully
# Row 1557 inserted successfully
# Row 1558 inserted successfully
# Row 1559 inserted successfully
# Row 1560 inserted successfully
# Row 1561 inserted successfully
# Row 1562 inserted successfully
# Row 1563 inserted successfully
# Row 1564 inserted successfully
# Row 1565 inserted successfully
# Row 1566 inserted successfully
# Row 1567 inserted successfully
# Row 1568 inserted successfully
# Row 1569 inserted successfully
# Row 1570 inserted successfully
# Row 1571 inserted successfully
# Row 1572 inserted successfully
# Row 1573 inserted successfully
# Row 1574 inserted successfully
# Row 1575 inserted successfully
# Row 1576 inserted successfully
# Row 1577 inserted successfully
# Row 1578 inserted successfully
# Row 1579 inserted successfully
# Row 1580 inserted successfully
# Row 1581 inserted successfully
# Row 1582 inserted successfully
# Row 1583 inserted successfully
# Row 1584 inserted successfully
# ...
# Row 11981 inserted successfully
# Row 11982 inserted successfully
# Row 11983 inserted successfully
# Row 11984 inserted successfully
# Row 11985 inserted successfully
# Row 11986 inserted successfully
# Row 11987 inserted successfully
# Row 11988 inserted successfully
# Row 11989 inserted successfully
# Row 11990 inserted successfully
# Row 11991 inserted successfully
# Row 11992 inserted successfully
# Row 11993 inserted successfully
# Row 11994 inserted successfully
# Row 11995 inserted successfully
# Row 11996 inserted successfully
# Row 11997 inserted successfully
# Row 11998 inserted successfully
# Row 11999 inserted successfully
# Row 12000 inserted successfully
# Row 12001 inserted successfully
# Row 12002 inserted successfully
# Row 12003 inserted successfully
# Row 12004 inserted successfully
# Row 12005 inserted successfully
# Row 12006 inserted successfully
# Row 12007 inserted successfully
# Row 12008 inserted successfully
# Row 12009 inserted successfully
# Row 12010 inserted successfully
# Row 12011 inserted successfully
# Row 12012 inserted successfully
# Row 12013 inserted successfully
# Row 12014 inserted successfully
# Row 12015 inserted successfully
# Row 12016 inserted successfully
# Row 12017 inserted successfully
# Row 12018 inserted successfully
# Row 12019 inserted successfully
# Row 12020 inserted successfully
# Row 12021 inserted successfully
# Row 12022 inserted successfully
# Row 12023 inserted successfully
# Row 12024 inserted successfully
# Row 12025 inserted successfully
# Row 12026 inserted successfully
# Row 12027 inserted successfully
# Row 12028 inserted successfully
# Row 12029 inserted successfully
# Row 12030 inserted successfully
# Row 12031 inserted successfully
# Row 12032 inserted successfully
# Row 12033 inserted successfully
# Row 12034 inserted successfully
# Row 12035 inserted successfully
# Row 12036 inserted successfully
# Row 12037 inserted successfully
# Row 12038 inserted successfully
# Row 12039 inserted successfully
# Row 12040 inserted successfully
# Row 12041 inserted successfully
# Row 12042 inserted successfully
# Row 12043 inserted successfully
# Row 12044 inserted successfully
# Row 12045 inserted successfully
# Row 12046 inserted successfully
# Row 12047 inserted successfully
# Row 12048 inserted successfully
# Row 12049 inserted successfully
# Row 12050 inserted successfully
# Row 12051 inserted successfully
# Row 12052 inserted successfully
# Row 12053 inserted successfully
# Row 12054 inserted successfully
# Row 12055 inserted successfully
# Row 12056 inserted successfully
# Row 12057 inserted successfully
# Row 12058 inserted successfully
# Row 12059 inserted successfully
# Row 12060 inserted successfully
# Row 12061 inserted successfully
# Row 12062 inserted successfully
# Row 12063 inserted successfully
# Row 12064 inserted successfully
# Row 12065 inserted successfully
# Row 12066 inserted successfully
# Row 12067 inserted successfully
# Row 12068 inserted successfully
# Row 12069 inserted successfully
# Row 12070 inserted successfully
# Row 12071 inserted successfully
# Row 12072 inserted successfully
# Row 12073 inserted successfully
# Row 12074 inserted successfully
# Row 12075 inserted successfully
# Row 12076 inserted successfully
# Row 12077 inserted successfully
# Row 12078 inserted successfully
# Row 12079 inserted successfully
# Row 12080 inserted successfully
# Row 12081 inserted successfully
# Row 12082 inserted successfully
# Row 12083 inserted successfully
# Row 12084 inserted successfully
# Row 12085 inserted successfully
# Row 12086 inserted successfully
# Row 12087 inserted successfully
# Row 12088 inserted successfully
# Row 12089 inserted successfully
# Row 12090 inserted successfully
# Row 12091 inserted successfully
# Row 12092 inserted successfully
# Row 12093 inserted successfully
# Row 12094 inserted successfully
# Row 12095 inserted successfully
# Row 12096 inserted successfully
# Row 12097 inserted successfully
# Row 12098 inserted successfully
# Row 12099 inserted successfully
# Row 12100 inserted successfully
# Row 12101 inserted successfully
# Row 12102 inserted successfully
# Row 12103 inserted successfully
# Row 12104 inserted successfully
# Row 12105 inserted successfully
# Row 12106 inserted successfully
# Row 12107 inserted successfully
# Row 12108 inserted successfully
# Row 12109 inserted successfully
# Row 12110 inserted successfully
# Row 12111 inserted successfully
# Row 12112 inserted successfully
# Row 12113 inserted successfully
# Row 12114 inserted successfully
# Row 12115 inserted successfully
# Row 12116 inserted successfully
# Row 12117 inserted successfully
# Row 12118 inserted successfully
# Row 12119 inserted successfully
# Row 12120 inserted successfully
# Row 12121 inserted successfully
# Row 12122 inserted successfully
# Row 12123 inserted successfully
# Row 12124 inserted successfully
# Row 12125 inserted successfully
# Row 12126 inserted successfully
# Row 12127 inserted successfully
# Row 12128 inserted successfully
# Row 12129 inserted successfully
# Row 12130 inserted successfully
# Row 12131 inserted successfully
# Row 12132 inserted successfully
# Row 12133 inserted successfully
# Row 12134 inserted successfully
# Row 12135 inserted successfully
# Row 12136 inserted successfully
# Row 12137 inserted successfully
# Row 12138 inserted successfully
# Row 12139 inserted successfully
# Row 12140 inserted successfully
# Row 12141 inserted successfully
# Row 12142 inserted successfully
# Row 12143 inserted successfully
# Row 12144 inserted successfully
# Row 12145 inserted successfully
# Row 12146 inserted successfully
# Row 12147 inserted successfully
# Row 12148 inserted successfully
# Row 12149 inserted successfully
# Row 12150 inserted successfully
# Row 12151 inserted successfully
# Row 12152 inserted successfully
# Row 12153 inserted successfully
# Row 12154 inserted successfully
# Row 12155 inserted successfully
# Row 12156 inserted successfully
# Row 12157 inserted successfully
# Row 12158 inserted successfully
# Row 12159 inserted successfully
# Row 12160 inserted successfully
# Row 12161 inserted successfully
# Row 12162 inserted successfully
# Row 12163 inserted successfully
# Row 12164 inserted successfully
# Row 12165 inserted successfully
# Row 12166 inserted successfully
# Row 12167 inserted successfully
# Row 12168 inserted successfully
# Row 12169 inserted successfully
# Row 12170 inserted successfully
# Row 12171 inserted successfully
# Row 12172 inserted successfully
# Row 12173 inserted successfully
# Row 12174 inserted successfully
# Row 12175 inserted successfully
# Row 12176 inserted successfully
# Row 12177 inserted successfully
# Row 12178 inserted successfully
# Row 12179 inserted successfully
# Row 12180 inserted successfully
# Row 12181 inserted successfully
# Row 12182 inserted successfully
# Row 12183 inserted successfully
# Row 12184 inserted successfully
# Row 12185 inserted successfully
# Row 12186 inserted successfully
# Row 12187 inserted successfully
# Row 12188 inserted successfully
# Row 12189 inserted successfully
# Row 12190 inserted successfully
# Row 12191 inserted successfully
# Row 12192 inserted successfully
# Row 12193 inserted successfully
# Row 12194 inserted successfully
# Row 12195 inserted successfully
# Row 12196 inserted successfully
# Row 12197 inserted successfully
# Row 12198 inserted successfully
# Row 12199 inserted successfully
# Row 12200 inserted successfully
# Row 12201 inserted successfully
# Row 12202 inserted successfully
# Row 12203 inserted successfully
# Row 12204 inserted successfully
# Row 12205 inserted successfully
# Row 12206 inserted successfully
# Row 12207 inserted successfully
# Row 12208 inserted successfully
# Row 12209 inserted successfully
# Row 12210 inserted successfully
# Row 12211 inserted successfully
# Row 12212 inserted successfully
# Row 12213 inserted successfully
# Row 12214 inserted successfully
# Row 12215 inserted successfully
# Row 12216 inserted successfully
# Row 12217 inserted successfully
# Row 12218 inserted successfully
# Row 12219 inserted successfully
# Row 12220 inserted successfully
# Row 12221 inserted successfully
# Row 12222 inserted successfully
# Row 12223 inserted successfully
# Row 12224 inserted successfully
# Row 12225 inserted successfully
# Row 12226 inserted successfully
# Row 12227 inserted successfully
# Row 12228 inserted successfully
# Row 12229 inserted successfully
# Row 12230 inserted successfully
# Row 12231 inserted successfully
# Row 12232 inserted successfully
# Row 12233 inserted successfully
# Row 12234 inserted successfully
# Row 12235 inserted successfully
# Row 12236 inserted successfully
# Row 12237 inserted successfully
# Row 12238 inserted successfully
# Row 12239 inserted successfully
# Row 12240 inserted successfully
# Row 12241 inserted successfully
# Row 12242 inserted successfully
# Row 12243 inserted successfully
# Row 12244 inserted successfully
# Row 12245 inserted successfully
# Row 12246 inserted successfully
# Row 12247 inserted successfully
# Row 12248 inserted successfully
# Row 12249 inserted successfully
# Row 12250 inserted successfully
# Row 12251 inserted successfully
# Row 12252 inserted successfully
# Row 12253 inserted successfully
# Row 12254 inserted successfully
# Row 12255 inserted successfully
# Row 12256 inserted successfully
# Row 12257 inserted successfully
# Row 12258 inserted successfully
# Row 12259 inserted successfully
# Row 12260 inserted successfully
# Row 12261 inserted successfully
# Row 12262 inserted successfully
# Row 12263 inserted successfully
# Row 12264 inserted successfully
# Row 12265 inserted successfully
# Row 12266 inserted successfully
# Row 12267 inserted successfully
# Row 12268 inserted successfully
# Row 12269 inserted successfully
# Row 12270 inserted successfully
# Row 12271 inserted successfully
# Row 12272 inserted successfully
# Row 12273 inserted successfully
# Row 12274 inserted successfully
# Row 12275 inserted successfully
# Row 12276 inserted successfully
# Row 12277 inserted successfully
# Row 12278 inserted successfully
# Row 12279 inserted successfully
# Row 12280 inserted successfully
# Row 12281 inserted successfully
# Row 12282 inserted successfully
# Row 12283 inserted successfully
# Row 12284 inserted successfully
# Row 12285 inserted successfully
# Row 12286 inserted successfully
# Row 12287 inserted successfully
# Row 12288 inserted successfully
# Row 12289 inserted successfully
# Row 12290 inserted successfully
# Row 12291 inserted successfully
# Row 12292 inserted successfully
# Row 12293 inserted successfully
# Row 12294 inserted successfully
# Row 12295 inserted successfully
# Row 12296 inserted successfully
# Row 12297 inserted successfully
# Row 12298 inserted successfully
# Row 12299 inserted successfully
# Row 12300 inserted successfully
# Row 12301 inserted successfully
# Row 12302 inserted successfully
# Row 12303 inserted successfully
# Row 12304 inserted successfully
# Row 12305 inserted successfully
# Row 12306 inserted successfully
# Row 12307 inserted successfully
# Row 12308 inserted successfully
# Row 12309 inserted successfully
# Row 12310 inserted successfully
# Row 12311 inserted successfully
# Row 12312 inserted successfully
# Row 12313 inserted successfully
# Row 12314 inserted successfully
# Row 12315 inserted successfully
# Row 12316 inserted successfully
# Row 12317 inserted successfully
# Row 12318 inserted successfully
# Row 12319 inserted successfully
# Row 12320 inserted successfully
# Row 12321 inserted successfully
# Row 12322 inserted successfully
# Row 12323 inserted successfully
# Row 12324 inserted successfully
# Row 12325 inserted successfully
# Row 12326 inserted successfully
# Row 12327 inserted successfully
# Row 12328 inserted successfully
# Row 12329 inserted successfully
# Row 12330 inserted successfully
# Row 12331 inserted successfully
# Row 12332 inserted successfully
# Row 12333 inserted successfully
# Row 12334 inserted successfully
# Row 12335 inserted successfully
# Row 12336 inserted successfully
# Row 12337 inserted successfully
# Row 12338 inserted successfully
# Row 12339 inserted successfully
# Row 12340 inserted successfully
# Row 12341 inserted successfully
# Row 12342 inserted successfully
# Row 12343 inserted successfully
# Row 12344 inserted successfully
# Row 12345 inserted successfully
# Row 12346 inserted successfully
# Row 12347 inserted successfully
# Row 12348 inserted successfully
# Row 12349 inserted successfully
# Row 12350 inserted successfully
# Row 12351 inserted successfully
# Row 12352 inserted successfully
# Row 12353 inserted successfully
# Row 12354 inserted successfully
# Row 12355 inserted successfully
# Row 12356 inserted successfully
# Row 12357 inserted successfully
# Row 12358 inserted successfully
# Row 12359 inserted successfully
# Row 12360 inserted successfully
# Row 12361 inserted successfully
# Row 12362 inserted successfully
# Row 12363 inserted successfully
# Row 12364 inserted successfully
# Row 12365 inserted successfully
# Row 12366 inserted successfully
# Row 12367 inserted successfully
# Row 12368 inserted successfully
# Row 12369 inserted successfully
# Row 12370 inserted successfully
# Row 12371 inserted successfully
# Row 12372 inserted successfully
# Row 12373 inserted successfully
# Row 12374 inserted successfully
# Row 12375 inserted successfully
# Row 12376 inserted successfully
# Row 12377 inserted successfully
# Row 12378 inserted successfully
# Row 12379 inserted successfully
# Row 12380 inserted successfully
# Row 12381 inserted successfully
# Row 12382 inserted successfully
# Row 12383 inserted successfully
# Row 12384 inserted successfully
# Row 12385 inserted successfully
# Row 12386 inserted successfully
# Row 12387 inserted successfully
# Row 12388 inserted successfully
# Row 12389 inserted successfully
# Row 12390 inserted successfully
# Row 12391 inserted successfully
# Row 12392 inserted successfully
# Row 12393 inserted successfully
# Row 12394 inserted successfully
# Row 12395 inserted successfully
# Row 12396 inserted successfully
# Row 12397 inserted successfully
# Row 12398 inserted successfully
# Row 12399 inserted successfully
# Row 12400 inserted successfully
# Row 12401 inserted successfully
# Row 12402 inserted successfully
# Row 12403 inserted successfully
# Row 12404 inserted successfully
# Row 12405 inserted successfully
# Row 12406 inserted successfully
# Row 12407 inserted successfully
# Row 12408 inserted successfully
# Row 12409 inserted successfully
# Row 12410 inserted successfully
# Row 12411 inserted successfully
# Row 12412 inserted successfully
# Row 12413 inserted successfully
# Row 12414 inserted successfully
# Row 12415 inserted successfully
# Row 12416 inserted successfully
# Row 12417 inserted successfully
# Row 12418 inserted successfully
# Row 12419 inserted successfully
# Row 12420 inserted successfully
# Row 12421 inserted successfully
# Row 12422 inserted successfully
# Row 12423 inserted successfully
# Row 12424 inserted successfully
# Row 12425 inserted successfully
# Row 12426 inserted successfully
# Row 12427 inserted successfully
# Row 12428 inserted successfully
# Row 12429 inserted successfully
# Row 12430 inserted successfully
# Row 12431 inserted successfully
# Row 12432 inserted successfully
# Row 12433 inserted successfully
# Row 12434 inserted successfully
# Row 12435 inserted successfully
# Row 12436 inserted successfully
# Row 12437 inserted successfully
# Row 12438 inserted successfully
# Row 12439 inserted successfully
# Row 12440 inserted successfully
# Row 12441 inserted successfully
# Row 12442 inserted successfully
# Row 12443 inserted successfully
# Row 12444 inserted successfully
# Row 12445 inserted successfully
# Row 12446 inserted successfully
# Row 12447 inserted successfully
# Row 12448 inserted successfully
# Row 12449 inserted successfully
# Row 12450 inserted successfully
# Row 12451 inserted successfully
# Row 12452 inserted successfully
# Row 12453 inserted successfully
# Row 12454 inserted successfully
# Row 12455 inserted successfully
# Row 12456 inserted successfully
# Row 12457 inserted successfully
# Row 12458 inserted successfully
# Row 12459 inserted successfully
# Row 12460 inserted successfully
# Row 12461 inserted successfully
# Row 12462 inserted successfully
# Row 12463 inserted successfully
# Row 12464 inserted successfully
# Row 12465 inserted successfully
# Row 12466 inserted successfully
# Row 12467 inserted successfully
# Row 12468 inserted successfully
# Row 12469 inserted successfully
# Row 12470 inserted successfully
# Row 12471 inserted successfully
# Row 12472 inserted successfully
# Row 12473 inserted successfully
# Row 12474 inserted successfully
# Row 12475 inserted successfully
# Row 12476 inserted successfully
# Row 12477 inserted successfully
# Row 12478 inserted successfully
# Row 12479 inserted successfully
# Row 12480 inserted successfully

# %%
insert_query = "INSERT INTO LIQUID_PARTICLE (Location, TS_DT, VALUE_1_0, VALUE_3_0, VALUE_5_0, VALUE_10_0, VALUE_15_0, VALUE_20_0, VALUE_25_0, VALUE_50_0) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"

stmt = ibm_db.prepare(conn, insert_query)

batch_data = []

for index, row in df.iterrows():
    location = row['Location']
    timestamp = row['Timestamp']
    c1 = row['1.0μｍ']
    c3 = row['3.0μｍ']
    c5 = row['5.0μｍ']
    c10 = row['10.0μｍ']
    c15 = row['15.0μｍ']
    c20 = row['20.0μｍ']
    c25 = row['25.0μｍ']
    c50 = row['50.0μｍ']

    batch_data.append([location, timestamp, c1, c3, c5, c10, c15, c20, c25, c50])

if ibm_db.execute(stmt, batch_data):
    print(f"{len(batch_data)} rows inserted successfully")
else:
    print(f"Error inserting batch: {ibm_db.stmt_errormsg()}")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [6], in <cell line: 21>()
#      17     c50 = row['50.0μｍ']
#      19     batch_data.append((location, timestamp, c1, c3, c5, c10, c15, c20, c25, c50,))
# ---> 21 if ibm_db.execute(stmt, batch_data):
#      22     print(f"{len(batch_data)} rows inserted successfully")
#      23 else:
#
# Exception: Param is not a tuple

# %%
batch_data
# Out:
# [('RP07',
#   Timestamp('2023-10-01 00:01:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:01:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:01:22'),
#   '18',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:01:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:01:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:02:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:01:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:02:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:00:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:01:22'),
#   '46193',
#   '674',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:02:52'),
#   '19',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:01:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:02:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:01:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:02:33'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:01:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:04:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:02:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:04:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:01:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:02:52'),
#   '47020',
#   '806',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:01:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:04:22'),
#   '31',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:02:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:04:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:02:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:04:03'),
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:02:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:05:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:04:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:05:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:03:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:04:22'),
#   '46558',
#   '700',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:02:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:05:52'),
#   '16',
#   '5',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:05:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:04:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:00:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:05:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:04:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:05:33'),
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:04:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:07:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:07:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:04:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:05:52'),
#   '44667',
#   '638',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:04:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:07:22'),
#   '31',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:05:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:02:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:08:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:07:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:07:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:05:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:07:03'),
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:05:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:07:22'),
#   '45639',
#   '677',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:08:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:06:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:05:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:08:52'),
#   '18',
#   '5',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:07:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:03:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:07:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:07:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:10:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:08:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:10:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:08:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:08:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:08:52'),
#   '48825',
#   '717',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:07:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:07:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:10:22'),
#   '19',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:08:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:05:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:08:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:10:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:08:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:11:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:10:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:11:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:10:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:09:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:10:22'),
#   '46042',
#   '626',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:08:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:11:52'),
#   '28',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:10:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:06:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:10:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:11:33'),
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:10:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:13:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:11:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:13:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:11:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:10:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:11:52'),
#   '50903',
#   '727',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:13:22'),
#   '20',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:10:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:11:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:08:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:11:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:13:03'),
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:11:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:14:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:13:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:14:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:13:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:12:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:13:22'),
#   '52123',
#   '733',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:14:52'),
#   '15',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:11:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:13:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:09:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:13:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:14:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:13:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:16:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:14:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:16:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:14:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:13:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:14:52'),
#   '47918',
#   '596',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:16:22'),
#   '10',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:13:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:14:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:11:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:14:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:16:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:14:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:17:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:16:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:17:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:16:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:15:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:16:22'),
#   '52805',
#   '748',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:17:52'),
#   '10',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:14:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:16:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:12:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:17:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:16:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:17:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:16:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:19:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:17:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:19:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:16:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:17:52'),
#   '51853',
#   '738',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:16:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:19:22'),
#   '14',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:17:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:14:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:19:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:17:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:19:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:17:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:20:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:19:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:20:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:18:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:19:22'),
#   '50223',
#   '690',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:17:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:20:52'),
#   '18',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:20:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:19:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:15:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:20:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:19:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:20:33'),
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:19:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:22:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:22:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:19:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:20:52'),
#   '51028',
#   '726',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:19:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:22:22'),
#   '13',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:20:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:17:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:23:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:22:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:22:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:20:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:22:03'),
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:20:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:22:22'),
#   '49108',
#   '697',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:23:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:21:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:20:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:23:52'),
#   '7',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:22:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:18:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:22:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:22:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:25:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:23:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:25:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:23:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:23:33'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:23:52'),
#   '49949',
#   '670',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:22:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:22:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:25:22'),
#   '18',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:23:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:20:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:23:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:25:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:23:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:26:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:25:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:26:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:25:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:24:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:25:22'),
#   '51371',
#   '696',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:23:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:26:52'),
#   '18',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:25:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:21:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:25:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:26:33'),
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:25:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:28:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:26:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:28:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:26:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:25:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:26:52'),
#   '51218',
#   '698',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:28:22'),
#   '7',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:25:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:26:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:23:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:26:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:28:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:26:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:29:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:28:23'),
#   '2605',
#   '38',
#   '28',
#   '9',
#   '4',
#   '2',
#   '1',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:29:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:28:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:27:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:28:22'),
#   '52942',
#   '741',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:29:52'),
#   '16',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:26:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:28:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:24:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:28:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:29:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:28:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:31:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:29:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:31:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:29:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:28:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:29:52'),
#   '51613',
#   '649',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:31:22'),
#   '23',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:28:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:29:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:26:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:29:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:31:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:29:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:32:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:31:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:32:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:31:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:30:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:31:22'),
#   '49224',
#   '621',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:32:52'),
#   '12',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:29:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:31:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:27:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:32:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:31:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:32:33'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:31:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:34:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:32:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:34:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:31:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:32:52'),
#   '51650',
#   '692',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:31:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:34:22'),
#   '20',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:32:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:29:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:34:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:32:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:34:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:32:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:35:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:34:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:35:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:33:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:34:22'),
#   '50598',
#   '673',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:32:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:35:52'),
#   '20',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:35:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:34:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:30:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:35:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:34:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:35:33'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:34:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:37:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:37:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:34:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:35:52'),
#   '52743',
#   '768',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:34:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:37:22'),
#   '15',
#   '5',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:35:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:32:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:38:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:37:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:37:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:35:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:37:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:35:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:37:22'),
#   '49197',
#   '663',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:38:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:36:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:35:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:38:52'),
#   '18',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:37:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:33:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:37:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:37:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:38:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:38:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:38:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:38:52'),
#   '51742',
#   '729',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:37:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:37:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:40:22'),
#   '24',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:38:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:35:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:38:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:40:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:38:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:40:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:39:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:40:22'),
#   '51628',
#   '664',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:38:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:41:52'),
#   '19',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:36:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:40:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:41:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:40:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:41:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:40:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:41:52'),
#   '48682',
#   '681',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:43:22'),
#   '19',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:40:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:38:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:41:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:43:03'),
#   '2',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:41:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:43:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:42:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:43:22'),
#   '49706',
#   '641',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:44:52'),
#   '7',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:41:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:39:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:43:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:44:33'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:43:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:44:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:43:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:44:52'),
#   '50939',
#   '682',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:46:22'),
#   '17',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:43:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:41:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:44:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:46:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:44:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:46:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:45:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:46:22'),
#   '51052',
#   '697',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:47:52'),
#   '22',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:44:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:42:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:47:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:46:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:47:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:46:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:46:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:47:52'),
#   '48664',
#   '677',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:46:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:49:22'),
#   '13',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:44:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:49:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:47:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:49:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:47:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:48:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:49:22'),
#   '49229',
#   '733',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:47:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:50:52'),
#   '16',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:45:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:50:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:49:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:50:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:49:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:49:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:50:52'),
#   '47327',
#   '706',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:49:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:52:22'),
#   '13',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:47:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:52:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:50:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:52:03'),
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:50:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:52:22'),
#   '49466',
#   '745',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:51:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:50:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:53:52'),
#   '21',
#   '5',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 00:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 00:48:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 00:52:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 00:52:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 00:55:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 00:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 00:55:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 00:53:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 00:53:33'),
#   '4',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 00:53:52'),
#   '48927',
#   '731',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 00:52:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 00:52:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 00:55:22'),
#   '20',
# ...
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:38:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:38:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:38:33'),
#   '2',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:38:52'),
#   '55365',
#   '815',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:37:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:37:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:40:22'),
#   '30',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:38:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:35:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:38:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:40:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:38:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:40:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:39:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:40:22'),
#   '45016',
#   '645',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:38:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:41:52'),
#   '25',
#   '6',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:40:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:36:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:40:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:41:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:40:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:41:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:40:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:41:52'),
#   '49683',
#   '757',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:43:22'),
#   '18',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:40:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:41:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:38:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:41:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:43:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:41:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:43:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:42:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:43:22'),
#   '49819',
#   '780',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:44:52'),
#   '7',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:41:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:43:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:39:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:43:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:44:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:43:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:44:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:43:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:44:52'),
#   '49870',
#   '731',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:46:22'),
#   '9',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:43:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:44:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:41:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:44:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:46:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:44:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:46:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:45:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:46:22'),
#   '50574',
#   '733',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:47:52'),
#   '13',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:44:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:46:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:42:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:47:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:46:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:47:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:46:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:46:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:47:52'),
#   '46916',
#   '713',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:46:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:49:22'),
#   '16',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:47:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:44:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:49:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:47:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:49:03'),
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:47:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:48:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:49:22'),
#   '51605',
#   '774',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:47:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:50:52'),
#   '17',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:49:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:45:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:50:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:49:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:50:33'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:49:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:49:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:50:52'),
#   '47138',
#   '764',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:49:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:52:22'),
#   '17',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:50:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:47:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:52:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:50:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:52:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:50:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:52:22'),
#   '48532',
#   '760',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:51:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:50:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:53:52'),
#   '9',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:52:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:48:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:52:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:52:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:55:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:55:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:53:55'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:53:33'),
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:53:52'),
#   '47042',
#   '728',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:52:31'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:52:02'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:55:22'),
#   '35',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:53:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:50:14'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:53:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP04',
#   Timestamp('2023-10-01 01:55:03'),
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP05',
#   Timestamp('2023-10-01 01:53:33'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP07',
#   Timestamp('2023-10-01 01:56:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP08',
#   Timestamp('2023-10-01 01:55:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP09',
#   Timestamp('2023-10-01 01:56:53'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP13',
#   Timestamp('2023-10-01 01:55:25'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP01',
#   Timestamp('2023-10-01 01:54:01'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP06',
#   Timestamp('2023-10-01 01:55:22'),
#   '49201',
#   '760',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP02',
#   Timestamp('2023-10-01 01:53:32'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP10',
#   Timestamp('2023-10-01 01:56:52'),
#   '14',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP11',
#   Timestamp('2023-10-01 01:55:23'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP12',
#   Timestamp('2023-10-01 01:51:44'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ('RP03',
#   Timestamp('2023-10-01 01:55:03'),
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'),
#  ...]

# %%
files = glob.glob(folder_name +"*.csv")              
dfs = []
for file in files:
    i = pd.read_csv(file,encoding="cp932")
    dfs.append(i)
df = pd.concat(dfs, axis=0, ignore_index = True)

# %%
import logging
custom_logger = logging.getLogger('custom_logger')
custom_logger.setLevel(logging.DEBUG)

handler = logging.StreamHandler()
handler.setLevel(logging.DEBUG) 
custom_logger.addHandler(handler)

logging.basicConfig()

custom_logger.warning('Watch out!')
custom_logger.info('I told you so')
print(custom_logger.handlers)
print(logging.root.level)
print(logging.root.handlers)
